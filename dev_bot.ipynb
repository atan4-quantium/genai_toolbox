# %%
from ghapi.all import GhApi
from pydantic import BaseSettings
import typer
from typing import Optional, List, Dict, Any, Union
import vertexai
from vertexai.generative_models import GenerativeModel, Part, FinishReason
import vertexai.preview.generative_models as generative_models

# %%
class Settings(BaseSettings):
    TOKEN: str
    OPEN_AI_KEY: str
    OWNER: str
    REPO_NAME: str
    PRICE_PER_TOKEN: float = 2.0000000000000002e-07
    MODEL_NAME: str = "gemini-1.5-flash"

    class Config:
        env_file = '.env'
        env_prefix = "PR_REVIEW_BOT_"

settings = Settings()

# %%
# Print the settings to ensure they are loaded correctly
print(f"OWNER: {settings.OWNER}")
print(f"REPO_NAME: {settings.REPO_NAME}")

# Initialize the GhApi with the provided settings
api = GhApi(token=settings.TOKEN, owner=settings.OWNER, repo=settings.REPO_NAME)
app = typer.Typer()
# Out:
# OWNER: Q-Retail
# REPO_NAME: qr_ngp_data_prep

# %%
def pull_pr_details(pr: Any) -> Dict[str, Union[str, float]]:
    pr_description = pr.body

    # Read all PR files
    pr_files = api.pulls.list_files(pr.number)
    pr_content = "\n\n\n".join(f"filename: {file.filename}: status: {file.status} patch: {get_patch(file)} " for file in pr_files)

    # Read all PR comments
    comments = api.issues.list_comments(pr.number)
    pr_comments = "\n".join(comment.body for comment in comments)

    text = f"pr_description\n {pr_description}, \npr_content\n = {pr_content}, \npr_comments\n = {pr_comments}"

    return text

def get_patch(pr_file: Any) -> str:
    return pr_file.patch if pr_file.changes != 0 else 'no changes'

def submit_review(pr: Any, review: Dict[str, Union[str, float]], label_name: str = "pr_review_bot") -> None:
    pr_number = pr.number

    # Create the label if it doesn't exist
    labels = api.issues.list_labels_for_repo()
    if not any(label.name == label_name for label in labels):
        api.issues.create_label(name=label_name, color="d73a4a", description="Label for autogenerated reviews")

    # Add the label to the PR
    api.issues.add_labels(issue_number=pr_number, labels=[label_name])

    # Submit the review
    api.pulls.create_review(pr_number, body=review['body'], event=review['event'])

# %%
generation_config = {
    "max_output_tokens": 8192,
    "temperature": 0.7,
    "top_p": 0.95,
}
def generate(text):
  vertexai.init(project="gcp-wow-corp-qretail-ngp-dev", location="us-central1")
  model = GenerativeModel(
    "gemini-1.5-flash",
  )
  responses = model.generate_content(
      [text],
      generation_config=generation_config,
      stream=False,
  )

  return responses

# %%
def review_pr(pr_number: Optional[int] = typer.Argument(None)) -> None:
    if pr_number is not None:
        pr = api.pulls.get(pr_number)
        pr_details = pull_pr_details(pr)

        prompt_template=f"""
            You are a genius software programmer data scientist. 
            Review this pull request for code quality, correctness, and potential improvements.
            Be super critical as this is production code we want to ensure it is concise and works well. 
            Pull request:
            {pr_details}

            **Please provide a concise review that includes:**
            * **Summary:** A brief overview of the changes and their impact.
            * **Concerns:** Any potential issues or risks identified.
            * **Questions:** Clarifying questions about the code or design.

            Think through step by step
        """
        review = generate(prompt_template)
        
        return review
    else:
        typer.echo("Please provide a valid PR number.")

# %%
def review_pr_specifics(pr_number: Optional[int] = typer.Argument(None)) -> None:
    if pr_number is not None:
        pr = api.pulls.get(pr_number)
        pr_details = pull_pr_details(pr)

        prompt_template=f"""
            You are a genius software programmer data scientist. 
            Review this pull request for code quality, correctness, and potential improvements.
            Be super critical as this is production code we want to ensure it is concise and works well. 
            Pull request:
            {pr_details}

            **Please provide a concise review that includes:**
            * **Suggestions:** Specific suggestions from the code on how to improve the code. 
            
            Provide ATLEAST 10 example improvements

            Think through step by step
        """
        review = generate(prompt_template)
        
        return review
    else:
        typer.echo("Please provide a valid PR number.")

# %%
pr_number = 472
review = review_pr_specifics(pr_number)
initial_bot_review = review.text
print(initial_bot_review)
event = "COMMENT"
action = {
        'body': initial_bot_review,
        'event': event
    }
pr = api.pulls.get(pr_number)
submit_review(pr, action)
# Out:
# ## Review of Pull Request
#
# This pull request refactors the `ly_data` portion of the pipeline to incorporate state-based assortment, a significant change impacting the entire data flow. While the validation steps seem thorough, there are several areas for improvement in code quality, correctness, and clarity.
#
# **Overall Observations:**
#
# * **Complex Logic:** The code is quite complex, with numerous nested WITH clauses and intricate logic for data imputation and filling. This makes it challenging to understand and maintain.
# * **Redundant Code:**  There's a lot of duplicated logic for handling different state-based columns.
# * **Lack of Comments:** Some sections lack sufficient comments, making it difficult to understand the purpose and reasoning behind specific operations.
# * **Potential Efficiency Issues:** The use of window functions and nested SELECT statements could potentially impact performance.
#
# **Specific Suggestions:**
#
# 1. **Refactor `ly_data_02_state_level_incrementality.sql`:**
#     * **Break down into smaller, modular components:**  Separate the logic for data imputation, forward filling, backward filling, and filling across states into distinct CTEs. This will make the code more readable and manageable.
#     * **Use functions for repetitive operations:**  Create functions for operations like suppressing promotions, calculating weighted averages, and applying bounds to simplify the code and reduce redundancy.
#     * **Replace hardcoded site IDs with dynamic queries:** Instead of hardcoding site IDs, use a dynamic query to fetch distinct `district` values from the base table. This will make the code more adaptable to future changes.
# 2. **Simplify `ly_data_03_deduped_state.sql`:**
#     * **Reduce redundant column selection:**  Instead of manually selecting all columns in the `state_nat_incrementality` CTE, use `* EXCEPT (column_name)` to avoid repetition.
# 3. **Refactor `ly_data_04_price_clustering.sql`:**
#     * **Use a single CTE for price clustering:**  Combine the separate CTEs for `shelf_price` and `price_per_unit` clustering into a single CTE.
#     * **Improve readability:**  Introduce descriptive names for CTEs and variables to enhance clarity.
# 4. **Simplify `ly_data_05_add_national_roll_up.sql`:**
#     * **Use a single CTE for national roll-up:**  Combine the `deduped_nat` and `deduped_state` CTEs into one.
#     * **Optimize `promo_keep_flag` CTE:**  Use a simpler logic for determining the `promo_keep_flag` instead of nested CASE statements.
# 5. **Refactor `ly_data_06_promotion_type_wide.sql`:**
#     * **Use dynamic queries for pivoting:**  Instead of hardcoding the site IDs in the PIVOT clause, use a dynamic query to fetch the site IDs.
#     * **Simplify column selection:**  Use `*` instead of manually listing all columns in the `state_financials_pivot` CTE.
# 6. **Improve `ly_data_07_promotion_type_long.sql`:**
#     * **Use a dynamic query for unpivoting:**  Instead of hardcoding the state-based columns in the UNPIVOT clause, use a dynamic query.
#     * **Make the code more readable:**  Introduce descriptive comments to explain the purpose of the unpivoting operation.
# 7. **Simplify `ly_data_08_cleansed_price_point_LY.sql`:**
#     * **Use a single CTE for pivoting:**  Combine the `cleansed_price_point_ly_promo_pivot` and `base_query` CTEs into one.
#     * **Use dynamic queries for pivoting and unpivoting:**  Instead of hardcoding site IDs and columns, use dynamic queries to make the code more adaptable.
# 8. **Improve `ly_data_98_ly_pmr_calendar.sql`:**
#     * **Use the correct `ly_data_07_promotion_type_long` reference:**  Ensure that the correct reference to the `ly_data_07_promotion_type_long` table is used.
# 9. **Update `dbt_project.yml`:**
#     * **Use `site_ids` variable:**  Use the `site_ids` variable defined in the `run.env` file to specify the site IDs in the `dbt_project.yml`.
# 10. **Add comments and documentation:**
#     * **Explain the purpose of each CTE and function:**  Include detailed comments to explain the logic and reasoning behind each step.
#     * **Update documentation:**  Update the documentation for the pipeline to reflect the changes made.
#
# **Example Improvement (ly_data_02_state_level_incrementality.sql):**
#
# **Original:**
#
# ```sql
# WITH factors_with_exclusion_promos AS (
#     SELECT
#         -- KEY
#         date.period_end_date, -- "YYYY-MM-DD"
#         base.district, -- String
#         base.store_id,-- Int
#         pa.price_family_code AS product_id, -- String
#         base.product_id AS sku, -- Required to calculate partial assortment related columns
#
#         -- PROMO INFORMATION
#         base.promo_flag, -- Int (1/0)
#         CAST(COALESCE({{ suppress_promotions('promo_flag', '0', var('ly_data_suppress_promo_fields')) }} ,0) AS NUMERIC) AS promo_flag, -- Int (1/0)
#         CAST(CASE WHEN standard_sell_price > 0.01 THEN standard_sell_price ELSE NULL END AS NUMERIC) AS standard_sell_price, -- Numeric
#         CAST({{ suppress_promotions('COALESCE(promo_depth, 0)', '0', var('ly_data_suppress_promo_fields')) }} AS NUMERIC) AS promo_depth, -- Numeric [0,1]
#         CAST({{ suppress_promotions('multibuy_trigger', '1', var('ly_data_suppress_promo_fields')) }} AS NUMERIC) AS multibuy_trigger, -- Int [1, Inf)
#         {{ suppress_promotions('parent_offer_type', 'NULL', var('ly_data_suppress_promo_fields')) }} AS parent_offer_type,
#         {{ suppress_promotions('brochure', '"02. Not on Brochure"', var('ly_data_suppress_promo_fields')) }} AS brochure,
#         {{ suppress_promotions('INITCAP(display_tactic, " ")', 'NULL', var('ly_data_suppress_promo_fields')) }} AS display_tactic,
#         {{ suppress_promotions('promo_type', 'NULL', var('ly_data_suppress_promo_fields')) }} AS promo_type,
#         -- EDLP
#         -- Varchar ('ALWAYS', 'DROPPED', NULL)
#         {{ suppress_promotions('price_type', 'NULL', var('ly_data_suppress_promo_fields')) }} AS price_type,
#         -- Member Promotion Flag
#         member_only,   -- Int (1/0)
#         -- Online Only Promotion Flag
#         online_only,   -- Int (1/0)
#
#         -- FINANCIALS
#         CAST(tax_rate AS NUMERIC) AS tax_rate,
#         CAST({{ suppress_promotions('units_redemption', 'units', var('ly_data_suppress_promo_fields'))}} AS NUMERIC) AS units_redemption,
#         CAST({{ suppress_promotions('units_redemption_denominator', 'units', var('ly_data_suppress_promo_fields'))}} AS NUMERIC) AS units_redemption_denominator,
#         CAST(CASE WHEN funding_per_unit IS NULL THEN 0 ELSE funding_per_unit END AS NUMERIC) AS funding_per_unit,
#         CASE
#             WHEN {{ suppress_promotions('promo_flag', '0', var('ly_data_suppress_promo_fields')) }} = 1 AND funding_per_unit IS NULL THEN 1
#             ELSE 0
#         END AS funding_null,
#         CAST(CASE WHEN purchase_cost > 0.01 THEN purchase_cost ELSE NULL END AS NUMERIC) AS purchase_cost, -- 0.01 is illegitimate RPP assigned when a product is delisted.
#         CAST(units AS NUMERIC) AS units,
#         CAST(sale_amount_including_tax AS NUMERIC) AS sale_amount_including_tax,
#         CAST(sale_amount_excluding_tax AS NUMERIC) AS sale_amount_excluding_tax,
#
#         -- NGS helper columns
#         -- sku_cnt_week_promo: number of items sold per week, district, ppg and promo_flag. Used to determine partial assortment promotions.
#         COUNT(DISTINCT sku)
#             OVER (PARTITION BY period_end_date, promo_flag, district, product_id) AS sku_cnt_week_promo,
#         -- unit_weight: units sold per week, district, ppg and promo_flag divided by the total units sold in that week, district, ppg and promo_flag
#         SAFE_DIVIDE(units, SUM(units) OVER (PARTITION BY period_end_date, promo_flag, district, product_id)) AS unit_weight
#     FROM factors_trimmed AS base
#     LEFT JOIN {{ ref('stores_to_exclude') }} AS stores_to_exclude
#     ON base.store_id = stores_to_exclude.supermarket_store_id
#     LEFT JOIN {{ ref('stg_01_product_attributes') }} AS pa
#     ON base.product_id = pa.product_id
#     WHERE stores_to_exclude.supermarket_store_id IS null
# ),
# ```
#
# **Improved:**
#
# ```sql
# {% macro suppress_promotions(column, replacement_value, fields) %}
#     COALESCE(
#         CASE
#             WHEN {{ fields }} IS NOT NULL THEN {{ replacement_value }}
#             ELSE {{ column }}
#         END,
#         {{ replacement_value }}
#     )
# {% endmacro %}
#
# WITH factors_trimmed AS (
#     -- ... (Existing code for factors_trimmed) ...
# ),
#
# -- Suppress promotions based on exclusion promotions
# filtered_factors AS (
#     SELECT
#         -- KEY
#         period_end_date,
#         district,
#         store_id,
#         product_id,
#         sku,
#
#         -- PROMO INFORMATION (suppressed based upon exclusion promotions)
#         {{ suppress_promotions('promo_flag', '0', var('ly_data_suppress_promo_fields')) }} AS promo_flag, -- Int (1/0)
#         {{ suppress_promotions('standard_sell_price', 'NULL', var('ly_data_suppress_promo_fields')) }} AS standard_sell_price, -- Numeric
#         {{ suppress_promotions('COALESCE(promo_depth, 0)', '0', var('ly_data_suppress_promo_fields')) }} AS promo_depth, -- Numeric [0,1]
#         {{ suppress_promotions('multibuy_trigger', '1', var('ly_data_suppress_promo_fields')) }} AS multibuy_trigger, -- Int [1, Inf)
#         {{ suppress_promotions('parent_offer_type', 'NULL', var('ly_data_suppress_promo_fields')) }} AS parent_offer_type,
#         {{ suppress_promotions('brochure', '"02. Not on Brochure"', var('ly_data_suppress_promo_fields')) }} AS brochure,
#         {{ suppress_promotions('INITCAP(display_tactic, " ")', 'NULL', var('ly_data_suppress_promo_fields')) }} AS display_tactic,
#         {{ suppress_promotions('promo_type', 'NULL', var('ly_data_suppress_promo_fields')) }} AS promo_type,
#         -- EDLP
#         -- Varchar ('ALWAYS', 'DROPPED', NULL)
#         {{ suppress_promotions('price_type', 'NULL', var('ly_data_suppress_promo_fields')) }} AS price_type,
#         -- Member Promotion Flag
#         member_only,   -- Int (1/0)
#         -- Online Only Promotion Flag
#         online_only,   -- Int (1/0)
#
#         -- FINANCIALS
#         CAST(tax_rate AS NUMERIC) AS tax_rate,
#         {{ suppress_promotions('units_redemption', 'units', var('ly_data_suppress_promo_fields'))}} AS units_redemption,
#         {{ suppress_promotions('units_redemption_denominator', 'units', var('ly_data_suppress_promo_fields'))}} AS units_redemption_denominator,
#         CAST(CASE WHEN funding_per_unit IS NULL THEN 0 ELSE funding_per_unit END AS NUMERIC) AS funding_per_unit,
#         CASE
#             WHEN promo_flag = 1 AND funding_per_unit IS NULL THEN 1
#             ELSE 0
#         END AS funding_null,
#         CAST(CASE WHEN purchase_cost > 0.01 THEN purchase_cost ELSE NULL END AS NUMERIC) AS purchase_cost, -- 0.01 is illegitimate RPP assigned when a product is delisted.
#         CAST(units AS NUMERIC) AS units,
#         CAST(sale_amount_including_tax AS NUMERIC) AS sale_amount_including_tax,
#         CAST(sale_amount_excluding_tax AS NUMERIC) AS sale_amount_excluding_tax,
#
#         -- NGS helper columns
#         -- sku_cnt_week_promo: number of items sold per week, district, ppg and promo_flag. Used to determine partial assortment promotions.
#         COUNT(DISTINCT sku)
#             OVER (PARTITION BY period_end_date, promo_flag, district, product_id) AS sku_cnt_week_promo,
#         -- unit_weight: units sold per week, district, ppg and promo_flag divided by the total units sold in that week, district, ppg and promo_flag
#         SAFE_DIVIDE(units, SUM(units) OVER (PARTITION BY period_end_date, promo_flag, district, product_id)) AS unit_weight
#     FROM factors_trimmed AS base
#     LEFT JOIN {{ ref('stores_to_exclude') }} AS stores_to_exclude
#     ON base.store_id = stores_to_exclude.supermarket_store_id
#     LEFT JOIN {{ ref('stg_01_product_attributes') }} AS pa
#     ON base.product_id = pa.product_id
#     WHERE stores_to_exclude.supermarket_store_id IS null
# ),
# ```
#
# This improvement demonstrates how to create a reusable macro for suppressing promotion fields, making the code more concise and easier to maintain. This approach can be applied to other repetitive operations throughout the pipeline.
#
# **Additional Considerations:**
#
# * **Testing:**  Ensure that the code is thoroughly tested with a comprehensive test suite.
# * **Performance Optimization:**  Profile the code to identify bottlenecks and optimize performance.
# * **Code Review:**  Encourage multiple code reviews to ensure that the changes are well-understood and meet the required quality standards.
#
# By addressing these suggestions, the pull request can be improved to deliver high-quality, maintainable, and efficient production code.
